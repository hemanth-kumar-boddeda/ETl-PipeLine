# %% [markdown]
# # ETL Project - ## Data Cleanup & Analysis

# %%
import pandas as pd
from sqlalchemy import create_engine

import pymysql
pymysql.install_as_MySQLdb()

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_2015file = "Resources/2015.csv"
csv_2016file = "Resources/2016.csv"
csv_2017file = "Resources/2017.csv"
data_2015df = pd.read_csv(csv_2015file)
data_2016df = pd.read_csv(csv_2016file)
data_2017df = pd.read_csv(csv_2017file)
data_2015df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %% [markdown]
# # Tranformation of data by cleaning, joining, filtering, aggregating

# %%
new_2015data_df = data_2015df[['Country', 'Happiness Rank', 'Happiness Score','Economy (GDP per Capita)','Family','Health (Life Expectancy)',
                               'Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual']].copy()

# %%
data_2016df
# Out:
#                   Country                           Region  Happiness Rank  \
# 0                 Denmark                   Western Europe               1
# 1             Switzerland                   Western Europe               2
# 2                 Iceland                   Western Europe               3
# 3                  Norway                   Western Europe               4
# 4                 Finland                   Western Europe               5
# 5                  Canada                    North America               6
# 6             Netherlands                   Western Europe               7
# 7             New Zealand        Australia and New Zealand               8
# 8               Australia        Australia and New Zealand               9
# 9                  Sweden                   Western Europe              10
# 10                 Israel  Middle East and Northern Africa              11
# 11                Austria                   Western Europe              12
# 12          United States                    North America              13
# 13             Costa Rica      Latin America and Caribbean              14
# 14            Puerto Rico      Latin America and Caribbean              15
# 15                Germany                   Western Europe              16
# 16                 Brazil      Latin America and Caribbean              17
# 17                Belgium                   Western Europe              18
# 18                Ireland                   Western Europe              19
# 19             Luxembourg                   Western Europe              20
# 20                 Mexico      Latin America and Caribbean              21
# 21              Singapore                Southeastern Asia              22
# 22         United Kingdom                   Western Europe              23
# 23                  Chile      Latin America and Caribbean              24
# 24                 Panama      Latin America and Caribbean              25
# 25              Argentina      Latin America and Caribbean              26
# 26         Czech Republic       Central and Eastern Europe              27
# 27   United Arab Emirates  Middle East and Northern Africa              28
# 28                Uruguay      Latin America and Caribbean              29
# 29                  Malta                   Western Europe              30
# 4                         0.382612           2.430182
# 5                         0.282662           2.294804
# 6                         0.287372           2.187264
# 7                         0.382817           2.046456
# 8                         0.384399           2.097538
# 9                         0.301184           2.065211
# 10                        0.085242           2.801757
# 11                        0.100107           2.898639
# 12                        0.221060           2.138506
# 13                        0.135639           2.218113
# 14                        0.298388           1.773869
# 15                        0.276732           2.015770
# 16                        0.251343           2.124210
# 17                        0.318834           1.619512
# 18                        0.265428           1.704144
# 19                        0.082288           2.509586
# 20                        0.324490           1.734704
# 21                        0.111093           2.769267
# 22                        0.036873           2.451862
# 23                        0.059740           2.614005
# 24                        0.132774           2.837155
# 25                        0.464308           1.216362
# 26                        0.153066           1.556863
# 27                        0.178062           2.172410
# 28                        0.077223           2.893891
# 29                        0.070984           2.307200
# ..                             ...                ...
# 125                       0.060241           2.224959
# 126                       0.104970           1.668191
# 127                       0.130062           1.844964
# 128                       0.068106           1.042941
# 129                       0.089848           1.687066
# 130                       0.025336           1.577868
# 131                       0.023029           0.814382
# 132                       0.057070           1.526363
# 133                       0.120328           1.727213
# 134                       0.138573           1.873983
# 135                       0.072712           2.081786
# 136                       0.053582           2.071238
# 137                       0.095375           1.597970
# 138                       0.119095           1.429835
# 139                       0.069720           1.614482
# 140                       0.061158           2.150801
# 141                       0.098583           0.377914
# 142                       0.060929           1.885631
# 143                       0.067232           1.584613
# 144                       0.099872           1.697168
# 145                       0.056767           1.345601
# 146                       0.116794           1.879567
# 147                       0.038948           1.673286
# 148                       0.110938           1.552312
# 149                       0.095665           1.837229
# 150                       0.455220           0.540061
# 151                       0.151347           1.061574
# 152                       0.066035           0.621130
# 153                       0.084148           1.683024
# 154                       0.056565           2.066005
#
# [155 rows x 12 columns]

# %%
new_2017data_df = data_2017df[['Country', 'Happiness.Rank', 'Happiness.Score','Economy..GDP.per.Capita.','Family','Health..Life.Expectancy.',
                               'Freedom','Generosity','Trust..Government.Corruption.','Dystopia.Residual']].copy()

# %%
renamed_2017df = new_2017data_df.rename(columns={"Happiness.Rank":"Happiness Rank", "Happiness.Score":"Happiness Score",
                                                "Economy..GDP.per.Capita.":"Economy (GDP per Capita)",
                                                 "Health..Life.Expectancy.":"Health (Life Expectancy)",
                                                 "Trust..Government.Corruption.":"Trust (Government Corruption)",
                                                "Dystopia.Residual":"Dystopia Residual"})
organized_2017df = renamed_2017df[["Country","Happiness Rank","Happiness Score","Economy (GDP per Capita)","Family","Health (Life Expectancy)",
                               "Freedom","Trust (Government Corruption)","Generosity","Dystopia Residual"]]
renamed_2017df
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# 5                 Netherlands               6            7.377
# 6                      Canada               7            7.316
# 7                 New Zealand               8            7.314
# 8                      Sweden               9            7.284
# 9                   Australia              10            7.284
# 10                     Israel              11            7.213
# 11                 Costa Rica              12            7.079
# 12                    Austria              13            7.006
# 29     0.210557                       0.070984           2.307200
# ..          ...                            ...                ...
# 125    0.246456                       0.060241           2.224959
# 126    0.183354                       0.104970           1.668191
# 127    0.201237                       0.130062           1.844964
# 128    0.385923                       0.068106           1.042941
# 129    0.182317                       0.089848           1.687066
# 130    0.256924                       0.025336           1.577868
# 131    0.270061                       0.023029           0.814382
# 132    0.325766                       0.057070           1.526363
# 133    0.250865                       0.120328           1.727213
# 134    0.228674                       0.138573           1.873983
# 135    0.287170                       0.072712           2.081786
# 136    0.216114                       0.053582           2.071238
# 137    0.189143                       0.095375           1.597970
# 138    0.157497                       0.119095           1.429835
# 139    0.097926                       0.069720           1.614482
# 140    0.311871                       0.061158           2.150801
# 141    0.099348                       0.098583           0.377914
# 142    0.207948                       0.060929           1.885631
# 143    0.208733                       0.067232           1.584613
# 144    0.489204                       0.099872           1.697168
# 145    0.104125                       0.056767           1.345601
# 146    0.285671                       0.116794           1.879567
# 147    0.266550                       0.038948           1.673286
# 148    0.264815                       0.110938           1.552312
# 149    0.196896                       0.095665           1.837229
# 150    0.252756                       0.455220           0.540061
# 151    0.493664                       0.151347           1.061574
# 152    0.354256                       0.066035           0.621130
# 153    0.204435                       0.084148           1.683024
# 154    0.280876                       0.056565           2.066005
#
# [155 rows x 10 columns]

# %%
new_2016data_df['year'] = 2016
new_2015data_df['year'] = 2015
renamed_2017df['year'] = 2017

# %%
# data_2015df.head()
all_years = [new_2015data_df, new_2016data_df, renamed_2017df]
new_all_years = pd.concat(all_years, sort=True)
new_all_years
# Out:
#                       Country  Dystopia Residual  Economy (GDP per Capita)  \
# 0                 Switzerland           2.517380                  1.396510
# 1                     Iceland           2.702010                  1.302320
# 2                     Denmark           2.492040                  1.325480
# 3                      Norway           2.465310                  1.459000
# 4                      Canada           2.451760                  1.326290
# 5                     Finland           2.619550                  1.290250
# 6                 Netherlands           2.465700                  1.329440
# 7                      Sweden           2.371190                  1.331710
# 8                 New Zealand           2.264250                  1.250180
# 9                   Australia           2.266460                  1.333580
# 10                     Israel           3.088540                  1.228570
# 11                 Costa Rica           3.177280                  0.955780
# 12                    Austria           2.533200                  1.337230
# 13                     Mexico           3.602140                  1.020540
# 14              United States           2.510110                  1.394510
# 15                     Brazil           3.260010                  0.981240
# 16                 Luxembourg           1.969610                  1.563910
# 17                    Ireland           1.975700                  1.335960
# 18                    Belgium           2.414840                  1.307820
# 19       United Arab Emirates           2.247430                  1.427270
# 20             United Kingdom           1.969940                  1.266370
# 21                       Oman           2.474890                  1.360110
# 22                  Venezuela           3.191310                  1.044240
# 23                  Singapore           1.885010                  1.521860
# 24                     Panama           2.848480                  1.063530
# 25                    Germany           2.115690                  1.327920
# 26                      Chile           2.675850                  1.107150
# 27                      Qatar           1.556740                  1.690420
# 28                     France           2.211260                  1.277780
# 29                  Argentina           2.836000                  1.053510
# ..                        ...                ...                       ...
# 125          Congo (Kinshasa)           2.224959                  0.092102
# 126                      Mali           1.668191                  0.476180
# 127               Ivory Coast           1.844964                  0.603049
# 140                  0.180747                       0.061158  2017
# 141                  0.341756                       0.098583  2017
# 142                  0.209930                       0.060929  2017
# 143                  0.375223                       0.067232  2017
# 144                  0.277321                       0.099872  2017
# 145                  0.310081                       0.056767  2017
# 146                  0.163486                       0.116794  2017
# 147                  0.229918                       0.038948  2017
# 148                  0.194129                       0.110938  2017
# 149                  0.247106                       0.095665  2017
# 150                  0.326425                       0.455220  2017
# 151                  0.500533                       0.151347  2017
# 152                  0.364509                       0.066035  2017
# 153                  0.151611                       0.084148  2017
# 154                  0.018773                       0.056565  2017
#
# [470 rows x 11 columns]

# %%
for i in new_all_years:
    print(i)
# Out:
# Country
# Dystopia Residual
# Economy (GDP per Capita)
# Family
# Freedom
# Generosity
# Happiness Rank
# Happiness Score
# Health (Life Expectancy)
# Trust (Government Corruption)
# year

# %% [markdown]
# # load data into database

# %%
rds_connection_string = "root@localhost/world_db"
engine = create_engine(f'mysql://{rds_connection_string}')

# %%
new_all_years.to_sql(name='happiness', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1192                 with util.safe_reraise():
# -> 1193                     self._dec_overflow()
#    1194         else:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1189             try:
# -> 1190                 return self._create_connection()
#    1191             except:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     670             self.starttime = time.time()
# --> 671             connection = pool._invoke_creator(self)
#     672             pool.logger.debug("Created new connection %r", connection)
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     409     def connect(self, *cargs, **cparams):
# --> 410         return self.dbapi.connect(*cargs, **cparams)
#     411
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\__init__.py in Connect(*args, **kwargs)
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     326         else:
# --> 327             self.connect()
#     328
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     597             self._get_server_information()
# --> 598             self._request_authentication()
#     599
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in _request_authentication(self)
#     851         self.write_packet(data)
# --> 852         auth_packet = self._read_packet()
#     853
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     682         packet = packet_type(buff, self.encoding)
# --> 683         packet.check_error()
#     684         return packet
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# OperationalError: (1045, "Access denied for user 'root'@'localhost' (using password: NO)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-18-dcd69b878299> in <module>()
# ----> 1 new_all_years.to_sql(name='happiness', con=engine, if_exists='append', index=False)
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2125         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2126                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2127                    dtype=dtype)
#    2128
#    2129     def to_pickle(self, path, compression='infer',
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1146                          if_exists=if_exists, index_label=index_label,
#    1147                          schema=schema, dtype=dtype)
# -> 1148         table.create()
#    1149         table.insert(chunksize)
#    1150         if (not name.isdigit() and not name.islower()):
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pandas\io\sql.py in create(self)
#     559
#     560     def create(self):
# --> 561         if self.exists():
#     562             if self.if_exists == 'fail':
#     563                 raise ValueError("Table '%s' already exists." % self.name)
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pandas\io\sql.py in exists(self)
#     547
#     548     def exists(self):
# --> 549         return self.pd_sql.has_table(self.name, self.schema)
#     550
#     551     def sql_schema(self):
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1174             self.connectable.dialect.has_table,
#    1175             name,
# -> 1176             schema or self.meta.schema,
#    1177         )
#    1178
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in run_callable(self, callable_, *args, **kwargs)
#    2053
#    2054         """
# -> 2055         with self.contextual_connect() as conn:
#    2056             return conn.run_callable(callable_, *args, **kwargs)
#    2057
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in contextual_connect(self, close_with_result, **kwargs)
#    2121         return self._connection_cls(
#    2122             self,
# -> 2123             self._wrap_pool_connect(self.pool.connect, None),
#    2124             close_with_result=close_with_result,
#    2125             **kwargs)
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2160             if connection is None:
#    2161                 Connection._handle_dbapi_exception_noconnection(
# -> 2162                     e, dialect, self)
#    2163             else:
#    2164                 util.reraise(*sys.exc_info())
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1474             util.raise_from_cause(
#    1475                 sqlalchemy_exception,
# -> 1476                 exc_info
#    1477             )
#    1478         else:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2156         dialect = self.dialect
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#    2160             if connection is None:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     401         """
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#     405         try:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     786     def _checkout(cls, pool, threadconns=None, fairy=None):
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#     790             fairy._pool = pool
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     530     @classmethod
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#     534             dbapi_connection = rec.get_connection()
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1191             except:
#    1192                 with util.safe_reraise():
# -> 1193                     self._dec_overflow()
#    1194         else:
#    1195             return self._do_get()
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     185         if value.__traceback__ is not tb:
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#     189 else:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1188         if self._inc_overflow():
#    1189             try:
# -> 1190                 return self._create_connection()
#    1191             except:
#    1192                 with util.safe_reraise():
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     348         """Called by subclasses to create a new ConnectionRecord."""
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#     352     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     475         self.__pool = pool
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#     479
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     669         try:
#     670             self.starttime = time.time()
# --> 671             connection = pool._invoke_creator(self)
#     672             pool.logger.debug("Created new connection %r", connection)
#     673             self.connection = connection
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     104                         if connection is not None:
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#     108             creator = pop_kwarg('creator', connect)
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     408
#     409     def connect(self, *cargs, **cparams):
# --> 410         return self.dbapi.connect(*cargs, **cparams)
#     411
#     412     def create_connect_args(self, url):
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\__init__.py in Connect(*args, **kwargs)
#      92     """
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#      96 from . import connections as _orig_conn
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     325             self._sock = None
#     326         else:
# --> 327             self.connect()
#     328
#     329     def _create_ssl_ctx(self, sslp):
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     596
#     597             self._get_server_information()
# --> 598             self._request_authentication()
#     599
#     600             if self.sql_mode is not None:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in _request_authentication(self)
#     850
#     851         self.write_packet(data)
# --> 852         auth_packet = self._read_packet()
#     853
#     854         # if authentication method isn't accepted the first byte
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     681
#     682         packet = packet_type(buff, self.encoding)
# --> 683         packet.check_error()
#     684         return packet
#     685
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1045, "Access denied for user 'root'@'localhost' (using password: NO)") (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
pd.read_sql_query('select * from happiness', con=engine).head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1192                 with util.safe_reraise():
# -> 1193                     self._dec_overflow()
#    1194         else:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1189             try:
# -> 1190                 return self._create_connection()
#    1191             except:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     670             self.starttime = time.time()
# --> 671             connection = pool._invoke_creator(self)
#     672             pool.logger.debug("Created new connection %r", connection)
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     409     def connect(self, *cargs, **cparams):
# --> 410         return self.dbapi.connect(*cargs, **cparams)
#     411
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\__init__.py in Connect(*args, **kwargs)
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     326         else:
# --> 327             self.connect()
#     328
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     597             self._get_server_information()
# --> 598             self._request_authentication()
#     599
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in _request_authentication(self)
#     851         self.write_packet(data)
# --> 852         auth_packet = self._read_packet()
#     853
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     682         packet = packet_type(buff, self.encoding)
# --> 683         packet.check_error()
#     684         return packet
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# OperationalError: (1045, "Access denied for user 'root'@'localhost' (using password: NO)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-19-dbfbef162d05> in <module>()
# ----> 1 pd.read_sql_query('select * from happiness', con=engine).head()
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     312     return pandas_sql.read_query(
#     313         sql, index_col=index_col, params=params, coerce_float=coerce_float,
# --> 314         parse_dates=parse_dates, chunksize=chunksize)
#     315
#     316
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1083         args = _convert_params(sql, params)
#    1084
# -> 1085         result = self.execute(*args)
#    1086         columns = result.keys()
#    1087
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#     974     def execute(self, *args, **kwargs):
#     975         """Simple passthrough to SQLAlchemy connectable"""
# --> 976         return self.connectable.execute(*args, **kwargs)
#     977
#     978     def read_table(self, table_name, index_col=None, coerce_float=True,
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2072         """
#    2073
# -> 2074         connection = self.contextual_connect(close_with_result=True)
#    2075         return connection.execute(statement, *multiparams, **params)
#    2076
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in contextual_connect(self, close_with_result, **kwargs)
#    2121         return self._connection_cls(
#    2122             self,
# -> 2123             self._wrap_pool_connect(self.pool.connect, None),
#    2124             close_with_result=close_with_result,
#    2125             **kwargs)
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2160             if connection is None:
#    2161                 Connection._handle_dbapi_exception_noconnection(
# -> 2162                     e, dialect, self)
#    2163             else:
#    2164                 util.reraise(*sys.exc_info())
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1474             util.raise_from_cause(
#    1475                 sqlalchemy_exception,
# -> 1476                 exc_info
#    1477             )
#    1478         else:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2156         dialect = self.dialect
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#    2160             if connection is None:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     401         """
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#     405         try:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     786     def _checkout(cls, pool, threadconns=None, fairy=None):
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#     790             fairy._pool = pool
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     530     @classmethod
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#     534             dbapi_connection = rec.get_connection()
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1191             except:
#    1192                 with util.safe_reraise():
# -> 1193                     self._dec_overflow()
#    1194         else:
#    1195             return self._do_get()
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     185         if value.__traceback__ is not tb:
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#     189 else:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1188         if self._inc_overflow():
#    1189             try:
# -> 1190                 return self._create_connection()
#    1191             except:
#    1192                 with util.safe_reraise():
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     348         """Called by subclasses to create a new ConnectionRecord."""
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#     352     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     475         self.__pool = pool
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#     479
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     669         try:
#     670             self.starttime = time.time()
# --> 671             connection = pool._invoke_creator(self)
#     672             pool.logger.debug("Created new connection %r", connection)
#     673             self.connection = connection
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     104                         if connection is not None:
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#     108             creator = pop_kwarg('creator', connect)
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     408
#     409     def connect(self, *cargs, **cparams):
# --> 410         return self.dbapi.connect(*cargs, **cparams)
#     411
#     412     def create_connect_args(self, url):
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\__init__.py in Connect(*args, **kwargs)
#      92     """
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#      96 from . import connections as _orig_conn
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     325             self._sock = None
#     326         else:
# --> 327             self.connect()
#     328
#     329     def _create_ssl_ctx(self, sslp):
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     596
#     597             self._get_server_information()
# --> 598             self._request_authentication()
#     599
#     600             if self.sql_mode is not None:
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in _request_authentication(self)
#     850
#     851         self.write_packet(data)
# --> 852         auth_packet = self._read_packet()
#     853
#     854         # if authentication method isn't accepted the first byte
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     681
#     682         packet = packet_type(buff, self.encoding)
# --> 683         packet.check_error()
#     684         return packet
#     685
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# ~\Desktop\Anaconda\envs\PythonData\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1045, "Access denied for user 'root'@'localhost' (using password: NO)") (Background on this error at: http://sqlalche.me/e/e3q8)
